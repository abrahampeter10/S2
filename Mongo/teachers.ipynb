# %%
import pymongo 
conn=pymongo.MongoClient("mongodb://localhost:27017/")
db=conn['teacher']
col=db['teacherlist']

# %%
col.insert_many([
    { "_id": 1, "name": "John Doe", "age": 35, "gender": "male" },
    { "_id": 2, "name": "Jane Smith", "age": 40, "gender": "female" },
    { "_id": 3, "name": "Michael Johnson", "age": 45, "gender": "male" },
    { "_id": 4, "name": "Emily Williams", "age": 30, "gender": "female" },
    { "_id": 5, "name": "Robert Brown", "age": 38, "gender": "male" },
    { "_id": 6, "name": "Emma Jones", "age": 33, "gender": "female" },
    { "_id": 7, "name": "William Davis", "age": 37, "gender": "male" },
    { "_id": 8, "name": "Olivia Miller", "age": 41, "gender": "female" },
    { "_id": 9, "name": "David Wilson", "age": 36, "gender": "male" },
    { "_id": 10, "name": "Sophia Moore", "age": 32, "gender": "female" },
    { "_id": 11, "name": "Richard Taylor", "age": 39, "gender": "male" },
    { "_id": 12, "name": "Isabella Anderson", "age": 43, "gender": "female" },
    { "_id": 13, "name": "Joseph Thomas", "age": 34, "gender": "male" },
    { "_id": 14, "name": "Mia Jackson", "age": 42, "gender": "female" },
    { "_id": 15, "name": "Charles White", "age": 36, "gender": "male" },
    { "_id": 16, "name": "Abigail Harris", "age": 31, "gender": "female" },
    { "_id": 17, "name": "Daniel Martin", "age": 44, "gender": "male" },
    { "_id": 18, "name": "Evelyn Thompson", "age": 38, "gender": "female" },
    { "_id": 19, "name": "Matthew Garcia", "age": 37, "gender": "male" },
    { "_id": 20, "name": "Sofia Martinez", "age": 35, "gender": "female" },
    { "_id": 21, "name": "Andrew Robinson", "age": 40, "gender": "male" },
    { "_id": 22, "name": "Grace Clark", "age": 33, "gender": "female" },
    { "_id": 23, "name": "Joshua Rodriguez", "age": 39, "gender": "male" },
    { "_id": 24, "name": "Avery Lewis", "age": 42, "gender": "female" },
    { "_id": 25, "name": "Christopher Lee", "age": 37, "gender": "male" },
    { "_id": 26, "name": "Chloe Walker", "age": 31, "gender": "female" },
    { "_id": 27, "name": "Kevin Hall", "age": 44, "gender": "male" },
    { "_id": 28, "name": "Zoey Allen", "age": 38, "gender": "female" },
    { "_id": 29, "name": "Brian Young", "age": 36, "gender": "male" },
    { "_id": 30, "name": "Harper King", "age": 34, "gender": "female" }
])
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 col.insert_many([
#       2     { "_id": 1, "name": "John Doe", "age": 35, "gender": "male" },
#       3     { "_id": 2, "name": "Jane Smith", "age": 40, "gender": "female" },
#       4     { "_id": 3, "name": "Michael Johnson", "age": 45, "gender": "male" },
#       5     { "_id": 4, "name": "Emily Williams", "age": 30, "gender": "female" },
#       6     { "_id": 5, "name": "Robert Brown", "age": 38, "gender": "male" },
#       7     { "_id": 6, "name": "Emma Jones", "age": 33, "gender": "female" },
#       8     { "_id": 7, "name": "William Davis", "age": 37, "gender": "male" },
#       9     { "_id": 8, "name": "Olivia Miller", "age": 41, "gender": "female" },
#      10     { "_id": 9, "name": "David Wilson", "age": 36, "gender": "male" },
#      11     { "_id": 10, "name": "Sophia Moore", "age": 32, "gender": "female" },
#      12     { "_id": 11, "name": "Richard Taylor", "age": 39, "gender": "male" },
#      13     { "_id": 12, "name": "Isabella Anderson", "age": 43, "gender": "female" },
#      14     { "_id": 13, "name": "Joseph Thomas", "age": 34, "gender": "male" },
#      15     { "_id": 14, "name": "Mia Jackson", "age": 42, "gender": "female" },
#      16     { "_id": 15, "name": "Charles White", "age": 36, "gender": "male" },
#      17     { "_id": 16, "name": "Abigail Harris", "age": 31, "gender": "female" },
#      18     { "_id": 17, "name": "Daniel Martin", "age": 44, "gender": "male" },
#      19     { "_id": 18, "name": "Evelyn Thompson", "age": 38, "gender": "female" },
#      20     { "_id": 19, "name": "Matthew Garcia", "age": 37, "gender": "male" },
#      21     { "_id": 20, "name": "Sofia Martinez", "age": 35, "gender": "female" },
#      22     { "_id": 21, "name": "Andrew Robinson", "age": 40, "gender": "male" },
#      23     { "_id": 22, "name": "Grace Clark", "age": 33, "gender": "female" },
#      24     { "_id": 23, "name": "Joshua Rodriguez", "age": 39, "gender": "male" },
#      25     { "_id": 24, "name": "Avery Lewis", "age": 42, "gender": "female" },
#      26     { "_id": 25, "name": "Christopher Lee", "age": 37, "gender": "male" },
#      27     { "_id": 26, "name": "Chloe Walker", "age": 31, "gender": "female" },
#      28     { "_id": 27, "name": "Kevin Hall", "age": 44, "gender": "male" },
#      29     { "_id": 28, "name": "Zoey Allen", "age": 38, "gender": "female" },
#      30     { "_id": 29, "name": "Brian Young", "age": 36, "gender": "male" },
#      31     { "_id": 30, "name": "Harper King", "age": 34, "gender": "female" }
#      32 ])
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\bulk.py:614, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#    (...)    610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
# --> 614     _raise_bulk_write_error(full_result)
#     615 return full_result
#
# File c:\Users\anton\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\bulk_shared.py:131, in _raise_bulk_write_error(full_result)
#     125         errmsg = (
#     126             "This MongoDB deployment does not support "
#     127             "retryable writes. Please add retryWrites=false "
#     128             "to your connection string."
#     129         )
#     130         raise OperationFailure(errmsg, code, full_result)
# --> 131 raise BulkWriteError(full_result)
#
# BulkWriteError: batch op errors occurred, full error: {'writeErrors': [{'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: teacher.teacherlist index: _id_ dup key: { _id: 1 }', 'keyPattern': {'_id': 1}, 'keyValue': {'_id': 1}, 'op': {'_id': 1, 'name': 'John Doe', 'age': 35, 'gender': 'male'}}], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}

# %%
print("All Student Documents:")
for doc in col.find():
    print(doc)
# Out:
# All Student Documents:
# {'_id': 1, 'name': 'John Doe', 'age': 35, 'gender': 'male'}
# {'_id': 2, 'name': 'Jane Smith', 'age': 40, 'gender': 'female'}
# {'_id': 3, 'name': 'Michael Johnson', 'age': 45, 'gender': 'male'}
# {'_id': 4, 'name': 'Emily Williams', 'age': 30, 'gender': 'female'}
# {'_id': 5, 'name': 'Robert Brown', 'age': 38, 'gender': 'male'}
# {'_id': 6, 'name': 'Emma Jones', 'age': 33, 'gender': 'female'}
# {'_id': 7, 'name': 'William Davis', 'age': 37, 'gender': 'male'}
# {'_id': 8, 'name': 'Olivia Miller', 'age': 41, 'gender': 'female'}
# {'_id': 9, 'name': 'David Wilson', 'age': 36, 'gender': 'male'}
# {'_id': 10, 'name': 'Sophia Moore', 'age': 32, 'gender': 'female'}
# {'_id': 11, 'name': 'Richard Taylor', 'age': 39, 'gender': 'male'}
# {'_id': 12, 'name': 'Isabella Anderson', 'age': 43, 'gender': 'female'}
# {'_id': 13, 'name': 'Joseph Thomas', 'age': 34, 'gender': 'male'}
# {'_id': 14, 'name': 'Mia Jackson', 'age': 42, 'gender': 'female'}
# {'_id': 15, 'name': 'Charles White', 'age': 36, 'gender': 'male'}
# {'_id': 16, 'name': 'Abigail Harris', 'age': 31, 'gender': 'female'}
# {'_id': 17, 'name': 'Daniel Martin', 'age': 44, 'gender': 'male'}
# {'_id': 18, 'name': 'Evelyn Thompson', 'age': 38, 'gender': 'female'}
# {'_id': 19, 'name': 'Matthew Garcia', 'age': 37, 'gender': 'male'}
# {'_id': 20, 'name': 'Sofia Martinez', 'age': 35, 'gender': 'female'}
# {'_id': 21, 'name': 'Andrew Robinson', 'age': 40, 'gender': 'male'}
# {'_id': 22, 'name': 'Grace Clark', 'age': 33, 'gender': 'female'}
# {'_id': 23, 'name': 'Joshua Rodriguez', 'age': 39, 'gender': 'male'}
# {'_id': 24, 'name': 'Avery Lewis', 'age': 42, 'gender': 'female'}
# {'_id': 25, 'name': 'Christopher Lee', 'age': 37, 'gender': 'male'}
# {'_id': 26, 'name': 'Chloe Walker', 'age': 31, 'gender': 'female'}
# {'_id': 27, 'name': 'Kevin Hall', 'age': 44, 'gender': 'male'}
# {'_id': 28, 'name': 'Zoey Allen', 'age': 38, 'gender': 'female'}
# {'_id': 29, 'name': 'Brian Young', 'age': 36, 'gender': 'male'}
# {'_id': 30, 'name': 'Harper King', 'age': 34, 'gender': 'female'}

# %%
col.update_many({"gender":"male"},{"$set":{"gender":"female"}})
# Out:
# UpdateResult({'n': 15, 'nModified': 15, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
col.update_one(
    {"_id": 1},
    {"$push": {"Subjects": "DBMS"}}
)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
